# %% [markdown]
# <a href="https://colab.research.google.com/github/AasthaNagargoje/ML_Practical/blob/main/prac8aastha.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#ML LAB 8

# %% [markdown]
# Aastha Nagargoje
# CS23168

# %%
#AIM:to apply principal Component Analysis for dimensionality reduction
#and visualize the transformed feature space

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# %%
iris=load_iris()
X = iris.data
y = iris.target

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_scaled)

# %%
print("Explained Variance Ratio:",pca.explained_variance_ratio_)
# Out:
# Explained Variance Ratio: [0.72962445 0.22850762]

# %%
plt.figure(figsize=(8,6))
plt.scatter(X_pca[:,0],X_pca[:,1],c=y)
plt.xlabel("Principal Component")
plt.ylabel(" Principal Component")
# Out:
# Text(0, 0.5, ' Principal Component')

# %%
plt.figure(figsize=(8,6))
plt.scatter(X_pca[:,0],X_pca[:,1],c=y)
plt.xlabel("Principal Component 1")
plt.ylabel("Principal Component 2")
plt.title("PCA - Iris Dataset")
plt.colorbar()
plt.show()

# %%
pca=PCA()
pca.fit(X_scaled)
plt.xlabel("Number of Components")
plt.ylabel("Explained Variance")
plt.plot(np.cumsum(pca.explained_variance_ratio_))
plt.show()
